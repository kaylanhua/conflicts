# %% [markdown]
# ## paper ingestion (historical)
#
# ** this is an edited version of ingestion.ipynb to focus only on the larger, seminal papers over the last few decades. cutoff is papers that have been cited 50 times.
#
# using the 2010 goldstone paper as the starting point, found [here](https://www.semanticscholar.org/paper/A-Global-Model-for-Forecasting-Political-Goldstone-Bates/5642a582b9a9a238e0211ca85e796e9238cd6057)

# %%
test_doi = '10.1111/J.1540-5907.2009.00426.X'

def create_url(id, is_doi=False, full_details=True):
    endpoint = "https://api.semanticscholar.org/graph/v1/paper/"
    fields = '?fields=title,abstract,url,year,authors,referenceCount,citationCount'
    if full_details:
        fields += ',citations,references'
    
    if is_doi:
        return endpoint + "DOI:" + id + fields
    else: 
        return endpoint + id + fields

# %%
import requests
import time

# calling the semantic scholar api
def api_call(api_endpoint):
    response = requests.get(api_endpoint)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(api_endpoint)
        return None

# a lot of error handling, hasn't broken so far
def try_api_call(api_endpoint):
    try:
        response = requests.get(api_endpoint)
        if response.status_code == 429:
            print("Rate limit reached. Waiting before retrying...")
            time.sleep(20)  # Sleep for a sec
            return api_call(api_endpoint)  # Retry the request
        response.raise_for_status()  # Will raise an HTTPError for other bad status codes
        return response.json()
        ## code to keep only the first 3 authors
        # if 'authors' in data and len(data['authors']) > 3:
        #         data['authors'] = data['authors'][:3]  
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err} - {api_endpoint}")
        return None
    except Exception as err:
        print(f"An error occurred: {err} - {api_endpoint}")
        return None

# %%
test_url = create_url(test_doi, is_doi=True, check_citations=True)
test_json = try_api_call(test_url)

# %%
import json
# pretty print json object
def pprint(data):
    print(json.dumps(data, indent=4, sort_keys=True))

# %%
# keywords
pred_keywords=[
    'machine learning', 
    'forecast',
    'predict',
    'regression', 
    'neural network', 
    'model',
    'projecting',
    'modeling',
    'classification', 
    'clustering', 
    'support vector machine', 
    'decision tree', 
    'random forest', 
    'learning', 
    'gradient boosting', 
    'natural language processing', 
    'algorithm', 
    'optimization', 
]
conflict_keywords=[
    'armed', 
    'civil',
    'battle', 
    'conflict',
    'warfare',
    'casualties',
    'combat',
]
all_keywords = pred_keywords + conflict_keywords

# %%
# loose check on title
def keyword_check(string):
    string = string.lower()
    return any(keyword in string for keyword in all_keywords)

## generally checks for prediction + conflicts related keywords (both must be present in the abstract)
def double_keyword_check(string):
    string = string.lower()
    match1 = any(keyword.lower() in string for keyword in pred_keywords)
    match2 = any(keyword.lower() in string for keyword in conflict_keywords)
    return match1 and match2

def paper_is_relevant(json_blob):
    title = json_blob['title']
    if double_keyword_check(title):
        return True
    else:
        abstract = json_blob['abstract']
        return double_keyword_check(abstract)

# %%
def filter_refs(paper_refs):
    # first pass at filtering out references that don't pass the general keyword check
    filtered_references = [
        ref for ref in paper_refs
        if keyword_check(ref['title'])
    ]
    return filtered_references

# %%
# testing all the helpers thus far
# key: paperId, value: [api call data object, how many times hit]
papers = {}

def add_to_dict(res):
    if res:
        # there was a response
        id = res['paperId']
        if id in papers:
            print('paper already in database')
        else:
            refs = filter_refs(res.pop('references', None))
            papers[id] = [res, refs, 1]

# %%
# not used i think
def from_a_node(key):
    value = papers[key]
    # iterate through the refs
    for ref in value[1]:
        ref_id = ref['paperId']
        if ref_id in papers:
            # if the ref is already in the database, increment the hit count
            papers[ref_id][2] += 1
        else:  
            # if the ref is not in the database, add it
            url = create_url(ref_id)
            res = api_call(url)
            if res['abstract'] and double_keyword_check(res['abstract']):
                add_to_dict(res)
    # touched again
    papers[key][2] += 1

# %%
# add the first node
url = create_url(test_doi, True, True)
res = try_api_call(url)
add_to_dict(res)

# print(papers)
print(papers)
# Out:
# {'5642a582b9a9a238e0211ca85e796e9238cd6057': [{'paperId': '5642a582b9a9a238e0211ca85e796e9238cd6057', 'url': 'https://www.semanticscholar.org/paper/5642a582b9a9a238e0211ca85e796e9238cd6057', 'title': 'A Global Model for Forecasting Political Instability', 'abstract': 'Examining onsets of political instability in countries worldwide from 1955 to 2003, we develop a model that distinguishes countries that experienced instability from those that remained stable with a two-year lead time and over 80% accuracy. Intriguingly, the model uses few variables and a simple specification. The model is accurate in forecasting the onsets of both violent civil wars and nonviolent democratic reversals, suggesting common factors in both types of change. Whereas regime type is typically measured using linear or binary indicators of democracy/autocracy derived from the 21-point Polity scale, the model uses a nonlinear five-category measure of regime type based on the Polity components. This new measure of regime type emerges as the most powerful predictor of instability onsets, leading us to conclude that political institutions, properly specified, and not economic conditions, demography, or geography, are the most important predictors of the onset of political instability.', 'year': 2010, 'referenceCount': 62, 'citationCount': 745, 'authors': [{'authorId': '48789243', 'name': 'J. Goldstone'}, {'authorId': '50010187', 'name': 'R. Bates'}, {'authorId': '144108346', 'name': 'David L. Epstein'}, {'authorId': '97823711', 'name': 'T. Gurr'}, {'authorId': '34957722', 'name': 'Mike Lustik'}, {'authorId': '104321452', 'name': 'Monty G. Marshall'}, {'authorId': '72284040', 'name': 'Jay Ulfelder'}, {'authorId': '145037489', 'name': 'Mark Woodward'}], 'citations': [{'paperId': 'c951ac9a54bba70c6e8337ab5815f3ac45434ec5', 'title': 'Modeling analysis of armed conflict risk in sub-Saharan Africa, 2000–2019'}, {'paperId': '6b61207075681296cb1709ec55b092b5877489b8', 'title': 'Predicting armed conflict using protest data'}, {'paperId': '5b5d1e14f01af4e1b77ab69f0b3ebe9cc7ca04f2', 'title': 'GT-CHES: Graph transformation for classification in human evolutionary systems'}, {'paperId': '19270648c69dd3d51a822c8b26ec78d81b5da0af', 'title': '“I’ll be the first one on the street to protest against the lockdown”: Economic grievances and antilockdown protests during the COVID-19 pandemic in high-income countries'}, {'paperId': '01fbeeb25e88f4ce4204b55ef59b4207dd3554f0', 'title': 'An automated pattern recognition system for conflict'}, {'paperId': 'b43f9eab421f3b1cf38c357b5fb55d235a386015', 'title': 'Civil Wars: Towards an Evolution of a Field, 2010-2016'}, {'paperId': '7cc7a46c9ee37e50353247e984ac9ce74d9b8e1f', 'title': 'The Cult of the Relevant: International Relations Scholars and Policy Engagement Beyond the Ivory Tower'}, {'paperId': '480ffb159e4b883e1867ebe998cabfdda4be67ed', 'title': 'Geopolitische Risiken strukturiert identifizieren'}, {'paperId': '081eb25fbcd0d148839a84aba753c1ea585f1487', 'title': 'Political Instability: An Impediment to Good Governance in Local Government – The Case of Selected Municipalities in South Africa'}, {'paperId': 'c096fe94092cbc01d10c412152fcfca8f60284d8', 'title': 'A hierarchical cluster approach\xa0toward understanding the regional variable in country conflict modeling'}, {'paperId': 'd7fd60f830d44e0c92ef4b651fb8d699d97148cd', 'title': 'Youth Bulge as a Peacebuilding Opportunity for Africa: The Case of Zimbabwe’s Youth Empowerment Programmes'}, {'paperId': 'bcc0c4f4d51063cf35babc94505ebc9dee390f6a', 'title': 'Conflict forecasting using remote sensing data: An application to the Syrian civil war'}, {'paperId': '23796b3015fe0fef3f93ad236f257865ceb04b3c', 'title': 'Future-proofing ecosystem restoration through enhancing adaptive capacity'}, {'paperId': '6094bd27dce10032f83f5ee5aaecffab949ff931', 'title': 'How Great is the Current Danger to Democracy? Assessing the Risk With Historical Data'}, {'paperId': '2f7057d8dad78605481df528a2ffd3891b6 ...

# %%
# Define the filename where you want to store the data
filename = 'hist_papers.json'

# Write the dictionary to a file as JSON
with open(filename, 'w') as file:
    json.dump(papers, file, indent=4)

print(f"Dictionary saved to {filename}")
# Out:
# Dictionary saved to hist_papers.json

# %%
def save_dict_to_file(graph_data, file_name):
    with open(file_name, 'w') as file:
        json.dump(graph_data, file, indent=4, default=str)  # Using default=str to handle non-serializable data
        
def save_queue_to_file(queue, file_name):
    with open(file_name, 'w') as file:
        listed = [list(tup) for tup in queue]
        json.dump(listed, file, indent=4, default=str)

# %%
## defaults to double keyword check (ML + conflicts) as filtering
def generate_reference_network(start_paper_id, max_depth=2, filter_func=double_keyword_check, res_name='graph.json'):
    seminal = {}
    
    ## setting up all variables
    graph = {}  # Initialize an empty graph, key: paper_id, value: paper_blob, list of references
    start_blob = try_api_call(create_url(start_paper_id))
    print(f"start_blob is {start_blob}")
    queue = [(start_paper_id, start_blob, 0)]  # Queue of (paper_id, current_depth)
    seminal[start_paper_id] = { "url": start_blob["url"], "title": start_blob["title"], "year": start_blob["year"], "citationCount": start_blob["citationCount"]}
    
    visited = set()  # Set of visited paper IDs to avoid duplicates
    save_interval = 1
    processed_papers = 0  

    while queue:
        current_paper_id, paper_info, current_depth = queue.pop(0)
        ## retrying failed api calls added to end of queue
        if not paper_info:
            url = create_url(current_paper_id)
            paper_info = try_api_call(url)
        if paper_info and current_paper_id not in visited and current_depth <= max_depth:
            print(f"Processing paper {current_paper_id} at depth {current_depth}")
            visited.add(current_paper_id)
            
            if paper_info['citationCount'] > 50:
                seminal[current_paper_id] = { "url": paper_info["url"], "title": paper_info["title"], "year": paper_info["year"], "citationCount": paper_info["citationCount"]}
                print(f"Seminal paper found: {paper_info['title']} with {paper_info["citationCount"]} citations")
    
            # Retrieve references
            if 'references' not in paper_info:
                print('no refs found')
                continue
            
            references = filter_refs(paper_info.pop('references', None))
            print("------- the num of references are: ", len(references))
            relevant_refs = []
            
            ## sheer off excess refs
            if len(references) > 100:
                references = references[:100]
            
            children = references
            
            ## retrieve citations, if requested
            if 'citations' in paper_info:
                if 'citations' in paper_info:
                    citations = filter_refs(paper_info.pop('citations', None))
                    print("------- the num of citations are: ", len(citations))
                    if len(citations) > 100:
                        citations = citations[:100]
                    children += citations
            
            print("------- the num of children are: ", len(children))
            
            ## iterate through references and citations
            for ref in children:
                ref_id = ref['paperId']
                if ref_id:
                    url = create_url(ref_id)
                    res = try_api_call(url)
                    
                    ## recompute 
                    if not res:
                        queue.append((ref_id, None, current_depth + 1))
                    elif res and res['abstract'] and filter_func(res['abstract']):
                        relevant_refs.append(ref_id) 
                        queue.append((ref_id, res, current_depth + 1))
                    
            ## add processed paper to graph
            graph[current_paper_id] = (paper_info, relevant_refs, current_depth)
            print("------- the rel references are: ", relevant_refs)

            processed_papers += 1
            
            # Save the graph every three papers processed
            if processed_papers % save_interval == 0:
                save_dict_to_file(graph, res_name)
                save_queue_to_file(queue, 'queue.json')
                save_dict_to_file(seminal, 'seminal.json')
                print(f"**** Saved backup of graph + queue at {processed_papers} papers.")
                
    return graph

# %%
## notes from random forest run 
## took 23 min 40 sec to get to 129 papers
## rate is about 5 papers per minute

# This will return a graph dictionary with each paper ID as keys and 
# the tuple (paper_info, lists of relevant references) as values.
# reference_network = generate_reference_network(test_paper_id)

# %% [markdown]
# ## running the analysis

# %%
## generally checks for keywords relating to prediction
def filter_pred(string):
    string = string.lower()
    match1 = any(keyword.lower() in string for keyword in pred_keywords)
    # for speed
    if not match1:
        return False
    match2 = any(keyword.lower() in string for keyword in conflict_keywords)
    return match1 and match2

# %%
## running the seminal paper algorithm 
# title: Comparing Random Forest with Logistic Regression for Predicting Class-Imbalanced Civil War Onset Data
# published: 2016

res = try_api_call(create_url(test_doi, is_doi=True, full_details=True))
hist_paper_id = '5642a582b9a9a238e0211ca85e796e9238cd6057'

# %%
## Actual generation
# time: 238m 46.5s
# 461 papers

hist_network = generate_reference_network(hist_paper_id, max_depth=3, filter_func=filter_pred, res_name='hist_papers.json')
# Out:
# start_blob is {'paperId': '5642a582b9a9a238e0211ca85e796e9238cd6057', 'url': 'https://www.semanticscholar.org/paper/5642a582b9a9a238e0211ca85e796e9238cd6057', 'title': 'A Global Model for Forecasting Political Instability', 'abstract': 'Examining onsets of political instability in countries worldwide from 1955 to 2003, we develop a model that distinguishes countries that experienced instability from those that remained stable with a two-year lead time and over 80% accuracy. Intriguingly, the model uses few variables and a simple specification. The model is accurate in forecasting the onsets of both violent civil wars and nonviolent democratic reversals, suggesting common factors in both types of change. Whereas regime type is typically measured using linear or binary indicators of democracy/autocracy derived from the 21-point Polity scale, the model uses a nonlinear five-category measure of regime type based on the Polity components. This new measure of regime type emerges as the most powerful predictor of instability onsets, leading us to conclude that political institutions, properly specified, and not economic conditions, demography, or geography, are the most important predictors of the onset of political instability.', 'year': 2010, 'referenceCount': 62, 'citationCount': 745, 'authors': [{'authorId': '48789243', 'name': 'J. Goldstone'}, {'authorId': '50010187', 'name': 'R. Bates'}, {'authorId': '144108346', 'name': 'David L. Epstein'}, {'authorId': '97823711', 'name': 'T. Gurr'}, {'authorId': '34957722', 'name': 'Mike Lustik'}, {'authorId': '104321452', 'name': 'Monty G. Marshall'}, {'authorId': '72284040', 'name': 'Jay Ulfelder'}, {'authorId': '145037489', 'name': 'Mark Woodward'}], 'citations': [{'paperId': 'c951ac9a54bba70c6e8337ab5815f3ac45434ec5', 'title': 'Modeling analysis of armed conflict risk in sub-Saharan Africa, 2000–2019'}, {'paperId': '6b61207075681296cb1709ec55b092b5877489b8', 'title': 'Predicting armed conflict using protest data'}, {'paperId': '5b5d1e14f01af4e1b77ab69f0b3ebe9cc7ca04f2', 'title': 'GT-CHES: Graph transformation for classification in human evolutionary systems'}, {'paperId': '19270648c69dd3d51a822c8b26ec78d81b5da0af', 'title': '“I’ll be the first one on the street to protest against the lockdown”: Economic grievances and antilockdown protests during the COVID-19 pandemic in high-income countries'}, {'paperId': '01fbeeb25e88f4ce4204b55ef59b4207dd3554f0', 'title': 'An automated pattern recognition system for conflict'}, {'paperId': 'b43f9eab421f3b1cf38c357b5fb55d235a386015', 'title': 'Civil Wars: Towards an Evolution of a Field, 2010-2016'}, {'paperId': '7cc7a46c9ee37e50353247e984ac9ce74d9b8e1f', 'title': 'The Cult of the Relevant: International Relations Scholars and Policy Engagement Beyond the Ivory Tower'}, {'paperId': '480ffb159e4b883e1867ebe998cabfdda4be67ed', 'title': 'Geopolitische Risiken strukturiert identifizieren'}, {'paperId': '081eb25fbcd0d148839a84aba753c1ea585f1487', 'title': 'Political Instability: An Impediment to Good Governance in Local Government – The Case of Selected Municipalities in South Africa'}, {'paperId': 'c096fe94092cbc01d10c412152fcfca8f60284d8', 'title': 'A hierarchical cluster approach\xa0toward understanding the regional variable in country conflict modeling'}, {'paperId': 'd7fd60f830d44e0c92ef4b651fb8d699d97148cd', 'title': 'Youth Bulge as a Peacebuilding Opportunity for Africa: The Case of Zimbabwe’s Youth Empowerment Programmes'}, {'paperId': 'bcc0c4f4d51063cf35babc94505ebc9dee390f6a', 'title': 'Conflict forecasting using remote sensing data: An application to the Syrian civil war'}, {'paperId': '23796b3015fe0fef3f93ad236f257865ceb04b3c', 'title': 'Future-proofing ecosystem restoration through enhancing adaptive capacity'}, {'paperId': '6094bd27dce10032f83f5ee5aaecffab949ff931', 'title': 'How Great is the Current Danger to Democracy? Assessing the Risk With Historical Data'}, {'paperId': '2f7057d8dad78605481df528a2ffd3891b670e97', 'title': 'Diplomats, Sol ...
# Processing paper 5642a582b9a9a238e0211ca85e796e9238cd6057 at depth 0
# Seminal paper found: A Global Model for Forecasting Political Instability with 745 citations
# ------- the num of references are:  24
# ------- the num of citations are:  273
# ------- the num of children are:  124
# ------- the rel references are:  ['257cb4317665951b77aa52d4510c31c06c11de87', '40a41644bf3682f9153b717e898c0e5364363618', 'b4fdbc2ba5d4278f39538cc1ad87048c3e2b84c6', '612de74da35f0270f7c56267c7313483df78ac6a', 'adf93e726f33066c6d9ac53332274b287878786d', '0a737f9ccd28a2409471388fedac2c07e95ae5c9', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6',
'257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '411ca55e7404d8da264b0588107ac1cc3a66b551', '655b14c0ce7c4cefc4333a04b1d55255fb22e61e', '4ab0061e426bd9d37b9b482d1f87a49b0053b443', '20753583aa06d8a0b7285923363201a09042b0ac', 'bdcef061089ba24bf7a3bb3913f11005983f7d13']
# **** Saved backup of graph + queue at 8 papers.
# Processing paper 2e8fe12635daa9aedab25eba850881bf26412cff at depth 1
# ------- the num of references are:  26
# ------- the num of citations are:  9
# ------- the num of children are:  35
# ------- the rel references are:  ['e4508323550d94fad642f89f4d956138427f5036', '54d750c48137cbce4003f5a918890e3d1eef05c4', '92b383dd1c96a8003943f8b56936c0b4b2dd7000', 'effee9141b5b1f3cba18e79d18b77cd94629eaba', 'adf93e726f33066c6d9ac53332274b287878786d', 'af3800bba6c9f0db5f16e7ea658df63ff4901d5f', 'c545ab4283787fe43cb0cf29de6b46e6bf511957', '5642a582b9a9a238e0211ca85e796e9238cd6057', '97e7552a9f6e1b0a9e5fbe187ea4e5a6fced377d', '17c7d2aada72fe59c8d282235b26089d526e44ee', 'f439aa97412d51a041ed3068563eafa347ff93a8']
# **** Saved backup of graph + queue at 9 papers.
# Processing paper 5aad2cf82e1717ab101786f14571bb318399da64 at depth 1
# Seminal paper found: Logistic Regression in Rare Events Data with 3912 citations
# ------- the num of references are:  24
# ------- the num of citations are:  353
# ------- the num of children are:  124
# ------- the rel references are:  ['e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', '16bed6b8cec51a6c75a541902e7874544c02e3aa', '49faafb31ce6026dcd1a2f2b3c7baf4389e33452']
# **** Saved backup of graph + queue at 10 papers.
# Processing paper c951ac9a54bba70c6e8337ab5815f3ac45434ec5 at depth 1
# ------- the num of references are:  42
# ------- the num of citations are:  0
# ------- the num of children are:  42
# ------- the rel references are:  ['5e2092e569a49b8404e4646eb7bfc8df51bc2fba', '01028e69dfd57d2738dcb39c057bbf952dbcb0af', '1e52a479cad4fedd32384aa346233203f9d19bbf', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '2a31dd2f126cd187cc5eb8dbbcd97ad42974ffc3', '26acad24d7bbaea5abfe66092b11bca450d8b8ac', '7ee54020f8b279d0a82afe22b466db95c498be90', '792e75d052a6fb31947b0161ded7c99c8f26a634', '52c2bed21c279b3d31806891756c61790b2399ad', 'c545ab4283787fe43cb0cf29de6b46e6bf511957', '5642a582b9a9a238e0211ca85e796e9238cd6057', '5254405a0d1000b57f32a2f6642d105e0b196caf', 'd4e1014f74c7f146be645860e66c80b9a35bf413']
# **** Saved backup of graph + queue at 11 papers.
# Processing paper 6b61207075681296cb1709ec55b092b5877489b8 at depth 1
# ------- the num of references are:  28
# ------- the num of citations are:  1
# ------- the num of children are:  29
# ------- the rel references are:  ['5e2092e569a49b8404e4646eb7bfc8df51bc2fba', '6136c8dc29bde2e0331a1eba5960b370c7eae7ca', 'e3cfeb4c6962676d491288ec55d40a69210e4a31', 'dd935eef90a1f85972047ce2c6a8e31a64aa98b0', '800368d107989fde4da18f254b660c4d384238d8', 'ae79cdde58981428c24212f2f95158487e102995', 'f1a390537e40e390f077d835bcde8532971db058', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', '195e90f8a356dc92212cb319a8525b2fe96cfba8', 'be6fac9e4ecbc3c8dc8d0fbe5dfa62810a10c51e', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '792e75d052a6fb31947b0161ded7c99c8f26a634', '257cb4317665951b77aa52d4510c31c06c11de87', '7636d23769df14264cc79b9aa4a8fa31f4216ab7', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'f7e013045c5610ae53c7ffa56cd5e014dcc9883a', '4c1bcea7ef5db705bd931526d855298fbd86b9eb', 'd266b6e24d6933680cc69d44d564d67e32a0c430']
# **** Saved backup of graph + queue at 12 papers.
# Processing paper 5b5d1e14f01af4e1b77ab69f0b3ebe9cc7ca04f2 at depth 1
# ------- the num of references are:  24
# ------- the num of citations are:  0
# ------- the num of children are:  24
# ------- the rel references are:  ['9935c8f8a37360196d92221ec092ae1880d272b8', '5642a582b9a9a238e0211ca85e796e9238cd6057']
# **** Saved backup of graph + queue at 13 papers.
# Processing paper c096fe94092cbc01d10c412152fcfca8f60284d8 at depth 1
# ------- the num of references are:  13
# ------- the num of citations are:  0
# ------- the num of children are:  13
# ------- the rel references are:  ['5951411bbe71df44dd27612afef45b702c828fb0', '3dd1e82f53e33825c3f0c46f8f111feb040514d8', '3d60598fae74dd51e3b55b261e52a0d486866f4c', '792e75d052a6fb31947b0161ded7c99c8f26a634', '5642a582b9a9a238e0211ca85e796e9238cd6057', '38b7496567ca4ab673e357ed215ff8ebf081f2cf']
# **** Saved backup of graph + queue at 14 papers.
# Processing paper 2f7057d8dad78605481df528a2ffd3891b670e97 at depth 1
# ------- the num of references are:  17
# ------- the num of citations are:  0
# ------- the num of children are:  17
# ------- the rel references are:  ['942875cd75279a695d842ee510c2a1c5f1860937', 'dd935eef90a1f85972047ce2c6a8e31a64aa98b0', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', 'c6e860a9ca0cc17075e155bbce4420812d6c485c', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '5642a582b9a9a238e0211ca85e796e9238cd6057']
# **** Saved backup of graph + queue at 15 papers.
# Processing paper 7ba687152ed7ab2d59e44563514b94454dde5ea7 at depth 1
# ------- the num of references are:  49
# ------- the num of citations are:  0
# ------- the num of children are:  49
# ------- the rel references are:  ['6f6769d45295d72a23c53fe9435cb14a57de067f', 'afbc16a3cdb5b641aa1e69f1a887349a35c05f47', '7ee54020f8b279d0a82afe22b466db95c498be90', '78bd7e481b7272d75fdd0dde6a1a5d7f5feb3aa4', '67cb36b7beb91d5e45d11c89c8a0ea21b1bf479e', 'c339c0558a730ae581b01ec43f1c35f974048e05', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'c0e12209003ef49523367d7eace8ca8ab0409ea6', '3d1ae201d7c588fd996d4350cd79e1dd16b00f39']
# **** Saved backup of graph + queue at 16 papers.
# Processing paper 2814386d119dd12615a3623fb5abea420ff3706a at depth 1
# ------- the num of references are:  5
# ------- the num of citations are:  1
# ------- the num of children are:  6
# ------- the rel references are:  ['5642a582b9a9a238e0211ca85e796e9238cd6057', '329e9a5e1435492a43e72d4132f5e6a41e1eaa34', '7cf5a3e7f0e6a1e9ae1532c83731571b9e948a4c']
# **** Saved backup of graph + queue at 17 papers.
# Processing paper 6dc502eb351d0754b53e37c13c41beb927a84b29 at depth 1
# ------- the num of references are:  31
# ------- the num of citations are:  1
# ------- the num of children are:  32
# ------- the rel references are:  ['0a370b9c1eac558098aac871055d4116b1bdb022', 'dd935eef90a1f85972047ce2c6a8e31a64aa98b0', 'e23afcd50cda337b6acf9b2d97a279289d732aaa', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', 'eba6b857d16235576d289db6da92fee7cefe39a1', 'a3f3dd219006c75bbb2f504c02a495a87614e336', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '792e75d052a6fb31947b0161ded7c99c8f26a634', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057',
# **** Saved backup of graph + queue at 20 papers.
# Processing paper 61d0212930010f66ac238ebce94bd1bec173241d at depth 1
# ------- the num of references are:  30
# ------- the num of citations are:  7
# ------- the num of children are:  37
# ------- the rel references are:  ['5e2092e569a49b8404e4646eb7bfc8df51bc2fba', 'dd935eef90a1f85972047ce2c6a8e31a64aa98b0', '2feaead175ab9e4a3af175abffc5e5f0c7be417b', 'e23afcd50cda337b6acf9b2d97a279289d732aaa', 'b880bd6873af49f88d6bc6cb556c14e49181a15c', '195e90f8a356dc92212cb319a8525b2fe96cfba8', '792e75d052a6fb31947b0161ded7c99c8f26a634', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '657fe7e9c5fb46863616a0a512eb9424cc078f7d', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '7a131f334b400cf73db7f4c7ae8f8e5808dddd15', 'adf93e726f33066c6d9ac53332274b287878786d', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', '11ab2b174f164909a13f124581eaa7114df9cd84', '5e2092e569a49b8404e4646eb7bfc8df51bc2fba', 'f54a6d3d71b08d8c7382bfc5a3eca08e84f0049d', '39b456e5749ee42d8457933eb3173070e75813cb', '25143b018e9b7f1967cd3cafb8f6c568bdc3f5e3']
# **** Saved backup of graph + queue at 21 papers.
# Processing paper 25143b018e9b7f1967cd3cafb8f6c568bdc3f5e3 at depth 1
# ------- the num of references are:  25
# ------- the num of citations are:  2
# ------- the num of children are:  27
# ------- the rel references are:  ['5e2092e569a49b8404e4646eb7bfc8df51bc2fba', '61d0212930010f66ac238ebce94bd1bec173241d', '3a5cff7c6eedf01d22d5b387c4f165035d019c55', 'b76bdc1d978d921d36069d66b80655ac0aff415b', '68af6eb9e2a97faa300553a2d16d6a4f08f1d482', 'd1b19d2a11528fbabbdc84e3c3235a5f5a3d4b26', '93f5802339f05cc8a02bfd1b67666a0199fd2002', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'f7e013045c5610ae53c7ffa56cd5e014dcc9883a', '801c235f7eeeeb276d82131a056ef3ece0ecd6ad', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', '5e2092e569a49b8404e4646eb7bfc8df51bc2fba']
# **** Saved backup of graph + queue at 22 papers.
# Processing paper 01028e69dfd57d2738dcb39c057bbf952dbcb0af at depth 1
# ------- the num of references are:  33
# ------- the num of citations are:  10
# ------- the num of children are:  43
# ------- the rel references are:  ['6e9e5bd5d0238825f982cc15566ef72d060c05fd', 'd23d12587b07d83ce28aabe41094a3d3ef9ac48c', 'e23afcd50cda337b6acf9b2d97a279289d732aaa', 'f1a390537e40e390f077d835bcde8532971db058', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', '2a31dd2f126cd187cc5eb8dbbcd97ad42974ffc3', '218c825a539d79989b852076b522e56b090afe40', '7ee54020f8b279d0a82afe22b466db95c498be90', '5642a582b9a9a238e0211ca85e796e9238cd6057', '3ed1fdca88b6d0cc5c3164a6bea435f32a42a30d', 'c951ac9a54bba70c6e8337ab5815f3ac45434ec5', '0e0bb9997cb7e343ae4a23312c1d2955493bef30', '2a49aa277ee380ff9f351fab09318aee8d1f2ec6', 'f77569407730d99c969ce34a040bd48dbca763ab']
# **** Saved backup of graph + queue at 23 papers.
# Processing paper 1c924ba9a4cee3b9c83bf6ad3661549be038a304 at depth 1
# ------- the num of references are:  13
# ------- the num of citations are:  3
# ------- the num of children are:  16
# ------- the rel references are:  ['2704e2cc969775d5941d0e489fb880ae43783b36', 'dd935eef90a1f85972047ce2c6a8e31a64aa98b0', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '657fe7e9c5fb46863616a0a512eb9424cc078f7d', '5642a582b9a9a238e0211ca85e796e9238cd6057', '4b6555beef240120bacb699c7d2f7c8e806b5747', '661984c20383f80ca5148d61c0fa70cab634fdc8', 'a0ebafb8e25ce7eff4ef32f514bd3541f88150ad']
# **** Saved backup of graph + queue at 24 papers.
# Processing paper 2704e2cc969775d5941d0e489fb880ae43783b36 at depth 1
# ------- the num of references are:  15
# ------- the num of citations are:  4
# ------- the num of children are:  19
# ------- the rel references are:  ['dd935eef90a1f85972047ce2c6a8e31a64aa98b0', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '661984c20383f80ca5148d61c0fa70cab634fdc8', '1c924ba9a4cee3b9c83bf6ad3661549be038a304', 'a0ebafb8e25ce7eff4ef32f514bd3541f88150ad']
# **** Saved backup of graph + queue at 25 papers.
# Processing paper 3dd1e82f53e33825c3f0c46f8f111feb040514d8 at depth 1
# ------- the num of references are:  23
# ------- the num of citations are:  2
# ------- the num of children are:  25
# ------- the rel references are:  ['0a370b9c1eac558098aac871055d4116b1bdb022', 'e23afcd50cda337b6acf9b2d97a279289d732aaa', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', 'eba6b857d16235576d289db6da92fee7cefe39a1', '5642a582b9a9a238e0211ca85e796e9238cd6057', '40a41644bf3682f9153b717e898c0e5364363618', 'adf93e726f33066c6d9ac53332274b287878786d', 'c096fe94092cbc01d10c412152fcfca8f60284d8']
# **** Saved backup of graph + queue at 26 papers.
# Processing paper b80b0ab1facb37c70270a118c8eb6f9763cefaa5 at depth 1
# ------- the num of references are:  35
# ------- the num of citations are:  5
# ------- the num of children are:  40
# ------- the rel references are:  ['5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '5642a582b9a9a238e0211ca85e796e9238cd6057', '86c1c52725a92f02a52bd9f7c6ad29abe69b4eb7', '9147952001d3371e7dfa5e17731c02198880b6a1', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', 'e2d2f1f17f3ceb3153e87d61bdcf2d668834a839']
# **** Saved backup of graph + queue at 27 papers.
# Processing paper 37a0aa8ec02dc36267d069787635916095d52b60 at depth 1
# ------- the num of references are:  36
# ------- the num of citations are:  5
# ------- the num of children are:  41
# ------- the rel references are:  ['ca23ae4851807cade78bd2671525a58cd31ec984', '7636d23769df14264cc79b9aa4a8fa31f4216ab7', '5642a582b9a9a238e0211ca85e796e9238cd6057', '83567e8ca85c09c7e5591b4af76eb37577b772e7', 'fb2d87e49bd796ca7b15464f1806369612ba3aeb', 'f3d8947832ebe02fc604f5b2425ea9af44962022']
# **** Saved backup of graph + queue at 28 papers.
# Processing paper 942875cd75279a695d842ee510c2a1c5f1860937 at depth 1
# ------- the num of references are:  20
# ------- the num of citations are:  14
# ------- the num of children are:  34
# ------- the rel references are:  ['bec9171943dddfd5086858f639c4a19250dca3b7', 'e23afcd50cda337b6acf9b2d97a279289d732aaa', '08e4b82f09b27ff25bcb6329f9ec8bc4a6a66348', 'd1b19d2a11528fbabbdc84e3c3235a5f5a3d4b26', 'f1a390537e40e390f077d835bcde8532971db058', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '195e90f8a356dc92212cb319a8525b2fe96cfba8', 'eba6b857d16235576d289db6da92fee7cefe39a1', '218c825a539d79989b852076b522e56b090afe40', '792e75d052a6fb31947b0161ded7c99c8f26a634', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'cedf9790639dcf3005cc063b2404a456ffa9851f', '2f7057d8dad78605481df528a2ffd3891b670e97', 'c29328f101c726bf59c7ec2b28814bbb0eae715e', '6136c8dc29bde2e0331a1eba5960b370c7eae7ca', '6e9e5bd5d0238825f982cc15566ef72d060c05fd', '5f08eaa18a9016b9969574cc5f3ea6a93ee11840']
# **** Saved backup of graph + queue at 29 papers.
# Processing paper 23ce1997237735a2acd2bb149bb5ba74c459a70b at depth 1
# ------- the num of references are:  72
# ------- the num of citations are:  1
# ------- the num of children are:  73
# ------- the rel references are:  ['636c857daa1a07c87d14d1637202073809547915', 'f1a390537e40e390f077d835bcde8532971db058', '218c825a539d79989b852076b522e56b090afe40', 'afbc16a3cdb5b641aa1e69f1a887349a35c05f47', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '6069e3148c40e37a5a2f4465d71771510f3fade6', '792e75d052a6fb31947b0161ded7c99c8f26a634', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', 'f13c163b292ddade636b907ad2dd0442da04355a', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '3ed1fdca88b6d0cc5c3164a6bea435f32a42a30d', '44e3d906e8f3f3d8e819283946484367b5e1d102', '7d5815d9f660054e9cfc458de1b4a120acdbf9de', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', '4b6555beef240120bacb699c7d2f7c8e806b5747', '42fb62d5807f08e6f3f3a5625a36890a35d04f32', 'aa39d92534798d2ac68f98b3ba6b37ade593198a', '8602b3eaec81ab746d463a6661030ba5145c1d81']
# **** Saved backup of graph + queue at 30 papers.
# Processing paper 3d60598fae74dd51e3b55b261e52a0d486866f4c at depth 1
# ------- the num of references are:  10
# ------- the num of citations are:  1
# ------- the num of children are:  11
# ------- the rel references are:  ['c166eaf05ac87ebd45836843c6c800447dc306e8', '3da6472f5461c6993fd082f6160edfa575664c8f', '792e75d052a6fb31947b0161ded7c99c8f26a634', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'c096fe94092cbc01d10c412152fcfca8f60284d8']
# **** Saved backup of graph + queue at 31 papers.
# Processing paper 80e68e6c36a9db8ea9fa37d9f011dc8d0306c222 at depth 1
# ------- the num of references are:  26
# ------- the num of citations are:  1
# ------- the num of children are:  27
# ------- the rel references are:  ['d649c26a7c2e9adecba919d2f9af397902ef989f', '131f8b78924c8be1ad2fc67896eec14037f716f7', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'ea2e5d8f941576e64a138643cc187c79f48fabe6', '612de74da35f0270f7c56267c7313483df78ac6a', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', 'fb2d87e49bd796ca7b15464f1806369612ba3aeb']
# **** Saved backup of graph + queue at 32 papers.
# Processing paper dd935eef90a1f85972047ce2c6a8e31a64aa98b0 at depth 1
# ------- the num of references are:  41
# ------- the num of citations are:  27
# ------- the num of children are:  68
# ------- the rel references are:  ['2feaead175ab9e4a3af175abffc5e5f0c7be417b', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '195e90f8a356dc92212cb319a8525b2fe96cfba8', '8b0db2c89eda11bafbb8e7948463e42f3f69fe0a', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '792e75d052a6fb31947b0161ded7c99c8f26a634', '109556565f19fd7a89ef240980d7a5deb50d274f', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '3b6ad7f6bc4332c430068216e22f9e4bdec671ea', '657fe7e9c5fb46863616a0a512eb9424cc078f7d', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'b07d7b0078eb12036da823de208eaad2fead9aea', '5e14f55da64c15748e2e94163465105f93b51b66', '28f1331354e185a9d63b6248ac48af3088d9524b', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6',
 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '3b6ad7f6bc4332c430068216e22f9e4bdec671ea', '5642a582b9a9a238e0211ca85e796e9238cd6057', '5c89027a9344c5ca324552f3918c2080e3640c17']
# **** Saved backup of graph + queue at 36 papers.
# Processing paper 091a28631bdc39796c45f92e1702b65c254200e9 at depth 1
# ------- the num of references are:  46
# ------- the num of citations are:  5
# ------- the num of children are:  51
# ------- the rel references are:  ['0a370b9c1eac558098aac871055d4116b1bdb022', '85d506c0b0900bcb4258446db6aba60f67baf6ce', 'd1b19d2a11528fbabbdc84e3c3235a5f5a3d4b26', 'aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '195e90f8a356dc92212cb319a8525b2fe96cfba8', 'eba6b857d16235576d289db6da92fee7cefe39a1', '035c40adc0fe3e9d69cb5d086fba7c2a2678d1cb', '792e75d052a6fb31947b0161ded7c99c8f26a634', '79f36e1827e7c1a845f1e52616434465401ad616', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '09f8d7290a3e05ba10bc7687915948f2207db443', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'adf93e726f33066c6d9ac53332274b287878786d', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', '4b6555beef240120bacb699c7d2f7c8e806b5747', '98c2f4d4f15f8dfae3e909ed428165aed0c50f8e']
# **** Saved backup of graph + queue at 37 papers.
# Processing paper c3113de684742ad605a0f44cc3c18f030c4a0d55 at depth 1
# ------- the num of references are:  17
# ------- the num of citations are:  0
# ------- the num of children are:  17
# ------- the rel references are:  ['5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', 'c6e860a9ca0cc17075e155bbce4420812d6c485c', '1ff0b08408655aad465358b98c0114ea62d6e893', '2fb1680649f11404cf5db6e39a74c36a5f44744f', '79f36e1827e7c1a845f1e52616434465401ad616', 'f4344d19ffa36006e1ea59d313f2c79a8f56fb98', '657fe7e9c5fb46863616a0a512eb9424cc078f7d', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '801c235f7eeeeb276d82131a056ef3ece0ecd6ad']
# **** Saved backup of graph + queue at 38 papers.
# Processing paper 2e251a253329ef98d68ac6d3ec28463894cc4aa1 at depth 1
# ------- the num of references are:  20
# ------- the num of citations are:  5
# ------- the num of children are:  25
# ------- the rel references are:  ['c6e860a9ca0cc17075e155bbce4420812d6c485c', '2fb1680649f11404cf5db6e39a74c36a5f44744f', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '01d667cc54cf1f6edeced24366c87e44d53e2c69', '801c235f7eeeeb276d82131a056ef3ece0ecd6ad', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', 'de425743d7c49f9288e00d97f0b67dcef2ef6f79', 'c0a180a9f15a215781fcc66343d70a95db53b238', '3ac3adc38e2a5fa06e635c4a2a873529ecb981fa']
# **** Saved backup of graph + queue at 39 papers.
# Processing paper e23afcd50cda337b6acf9b2d97a279289d732aaa at depth 1
# ------- the num of references are:  19
# ------- the num of citations are:  24
# ------- the num of children are:  43
# ------- the rel references are:  ['aeac3f12ec7b2a490f1f67dcb6c13bc58faaed83', '5e14deb89c8cfb787f9cd63de081c9bbd30b59f7', '792e75d052a6fb31947b0161ded7c99c8f26a634', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '6dc502eb351d0754b53e37c13c41beb927a84b29', 'c29328f101c726bf59c7ec2b28814bbb0eae715e', '61d0212930010f66ac238ebce94bd1bec173241d', '01028e69dfd57d2738dcb39c057bbf952dbcb0af', '3dd1e82f53e33825c3f0c46f8f111feb040514d8', '7744977780aef5e5b76f33717dce09facb34f49e', '6e9e5bd5d0238825f982cc15566ef72d060c05fd', '942875cd75279a695d842ee510c2a1c5f1860937', '188cb19ed3adb7269401f091d03164ba684f30e5', 'b250742c9859459565a9fd5bfe728075a0452583']
# **** Saved backup of graph + queue at 40 papers.
# Processing paper 406529f63ded0bd26a0972ec9336876639e653cd at depth 1
# ------- the num of references are:  12
# ------- the num of citations are:  8
# ------- the num of children are:  20
# ------- the rel references are:  ['d5c97af94713b7f2ecf6158d24b6146db489e5a4', '5383652ae31f090c33bebe2ed9dd7cba7f0dff6e', 'c339c0558a730ae581b01ec43f1c35f974048e05', '5642a582b9a9a238e0211ca85e796e9238cd6057', '9e925d5b330dcc78e59699cd4377fc5865b657f2', '8b4533e8480b1ccbddc5cb151b564ea297980f46', '43521ff3f560afb1e5433a68e459e736f9a5e695']
# **** Saved backup of graph + queue at 41 papers.
# Processing paper c80410e3dc6b180304cdaeae24dbd0ad35c9cc6d at depth 1
# ------- the num of references are:  31
# ------- the num of citations are:  5
# ------- the num of children are:  36
# ------- the rel references are:  ['7636d23769df14264cc79b9aa4a8fa31f4216ab7', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'f8711fa6943991254c132d3030780616dc4c06db']
# **** Saved backup of graph + queue at 42 papers.
# Processing paper f986a2daadbf13b6a5cb983df204f0dbb0f65292 at depth 1
# ------- the num of references are:  9
# ------- the num of citations are:  13
# ------- the num of children are:  22
# ------- the rel references are:  ['4cd555727ee90fbc7edbbd02598d4dbc38c52ca9', '5642a582b9a9a238e0211ca85e796e9238cd6057', '3af63a0af1ba1bf8eecd59978d2f7729ee55b1ff', '2a49aa277ee380ff9f351fab09318aee8d1f2ec6', 'f18e576b6b9b9cffccc98ee2082413dce12810af', 'c3fd83132f20503b234406a9e65efbe0a7bc7af3', '3ca50610e34cc8273bc946514afcfc99a0752a1c', '59684871143b954154584d38be5d879ceea0c2ab', 'a627fc58aa8d1473708d3538d046431adfc5d117']
# **** Saved backup of graph + queue at 43 papers.
# Processing paper 693d4b0d210bbe37afaf6e7d21abbe396da61c9d at depth 1
# ------- the num of references are:  14
# ------- the num of citations are:  1
# ------- the num of children are:  15
# ------- the rel references are:  ['26f7acd25f83baf7ae3740de9203270f0b877e8a', 'c6e860a9ca0cc17075e155bbce4420812d6c485c', '5642a582b9a9a238e0211ca85e796e9238cd6057', 'f7c63cf7d15df45999067fcdd8e3bcfc56c9e3c6', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6']
# **** Saved backup of graph + queue at 44 papers.
# Processing paper 6f692bb34e7a3afc96ce1ab5817ba8b3115cdcb0 at depth 1
# ------- the num of references are:  3
# ------- the num of citations are:  0
# ------- the num of children are:  3
# ------- the rel references are:  ['5642a582b9a9a238e0211ca85e796e9238cd6057']
# **** Saved backup of graph + queue at 45 papers.
# Processing paper a25a988869a4cd253b1809355d8cfc251e0b7f98 at depth 1
# ------- the num of references are:  8
# ------- the num of citations are:  13
# ------- the num of children are:  21
# ------- the rel references are:  ['6306b408f462e83e56159f785fb92e96f040d49b', '8270337eaabc7ecd64b568a13e56f90b4ae09b11', '5642a582b9a9a238e0211ca85e796e9238cd6057', '240443fa31d8b181f94c8b593c26bd939bfa9b0c', '19c0c757fbc744a490b8954e197de51551ce5705', 'b8e5e2d39503de867f10fb2a5ddb18c4608183ef', '97c3d68a25e2c9bb112450e8ba01b8f0cf422c4b', '7eb89a6be7172b3fbcbaa3c10dcbd255760f02d9', '38be08ab4720dad5fe664278b9edb9563e95bfd9', '8d83463c15103d380da3ef782de37b61d7738dc9']
# **** Saved backup of graph + queue at 46 papers.
# Processing paper 20407577c7c0a52fa2479b6b195bd809adc9d305 at depth 1
# ------- the num of references are:  17
# ------- the num of citations are:  1
# ------- the num of children are:  18
# ------- the rel references are:  ['c6e860a9ca0cc17075e155bbce4420812d6c485c', '2fb1680649f11404cf5db6e39a74c36a5f44744f', '257cb4317665951b77aa52d4510c31c06c11de87', '5642a582b9a9a238e0211ca85e796e9238cd6057', '01d667cc54cf1f6edeced24366c87e44d53e2c69', 'e3004293f727e6cfaa0b5e3cd918efbf4310a9f6', 'de425743d7c49f9288e00d97f0b67dcef2ef6f79']
# **** Saved backup of graph + queue at 47 papers.
# ...
# Processing paper 2edd2a4513345102dd721d3c042e1e33eac16ef7 at depth 3
# Seminal paper found: The Power to Hurt: Costly Conflict with Completely Informed States with 221 citations
# ------- the num of references are:  6
# ------- the num of citations are:  78
# ------- the num of children are:  84
# HTTP error occurred: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/0a577ebd728080640ba1f6da20e99cf6e9526c8e?fields=title,abstract,url,year,authors,referenceCount,citationCount,citations,references - https://api.semanticscholar.org/graph/v1/paper/0a577ebd728080640ba1f6da20e99cf6e9526c8e?fields=title,abstract,url,year,authors,referenceCount,citationCount,citations,references
# ------- the rel references are:  ['3a1f1ecba16183a318e99ebf72fe6fa40b42e330', '8c74fa8a7636c82ab7c460aa25c7fb6b61eace9f', '76aa3f295a87c49352450a0b5787179d5907a387', '57608e8d46ecf84063a320425ac20ad86a3c2143', '5b277722847508b6ac770b27f3a97e65bdf7906d', '6dbca7392a35b24299f911248a5c8f3c14380c05', '85dfbde25315f858b8f7ea4cb18bef676107d401', 'cd5e6f1e93a40c789a64e6e64edb5c99d988496e', 'd81bff0d102c934c3d27c09827a4eded8ccb824b', '4d7e87257ba47faf44a1411b98166239fc2aed81', 'd36ef82ee527891d0fbf455858831cdbaed253d3', 'f6770dbbeaffe708cec6fd4236cc7dea49fe55f1', '5a81afc9a8380935dd0f98197a67f4c957424dee', 'c0594147d2eb26405eecfc8be38c75a91ee4f107', '5949adf9c0182c824edc147e4ec841f18d0a8300', '7846eb8129e1c19e2279b5b9d8d36f5004f0ebf9', '67541daf25c50ae0adda41b809158ed3b425ba28', '62a86c39a762a54d61a167b376060be292e6bc72', 'a1819c5818e8a7822fe83c1fa48d3b877f451cfa', 'c039809529e103a807e100fff0967b3508cd96f1', '44928705e86e65e58fa929f2c11a3bba15293a33', '9d0ff61307da885f972f3795c9f32b1939b3a125', '91bc88c65ab0922d5b48faa7d7016875cf49ba4f', 'dbf7ce47b1f396ef890d01e706c135f3a48fc4cb', '895a9d855b65799dd45049f5225be04138df8ce4', '4c005c4e061cf026445b79c62dbff0d1b7d38885']
# **** Saved backup of graph + queue at 453 papers.
# Processing paper 44de04a56fbc293f5a3a2a6f11a5238c36f7b941 at depth 3
# Seminal paper found: How Civil Wars End with 266 citations
# ------- the num of references are:  7
# ------- the num of citations are:  160
# ------- the num of children are:  107
# ------- the rel references are:  ['d7f60162a18470ad42c75644ee16013d63ce16f7', '865c283a5a483df3692f22d2e3d59ca445fa9e9c', '91b7ee27cf5967149bd4fba4ad5caac87aba6121', 'be4ff1672ae889191633fa13c0af0df031a95726', '8c74fa8a7636c82ab7c460aa25c7fb6b61eace9f', '89e4796b57d5e24e80ef8d4b7246047485a0afbc', '12508b2df8731d836f8bdebac0fb12d0218e9175', 'ce02f8c1056e6a8abb8632779a9f32cbe6c60199', '6004057c91d4ed6a9e30d13de429eb2f98c5d113', '5f3f9a6f0ef4b1d2682142eeca32ac5026df7e27', '336d501500ce4b4edee0e9e3248a36b3b1bcb4a7', '11814271b1b88f806807a0156cb585f8e67f107b', 'ed9e2b58be8d252bb8dc6322cbe7c9d4fba32988', 'ac02a6f5f0a5535f15ab7b68c2de67aede03af66', '45ad10d62de2b79f9d7efb449c691520e94a9d6d', 'ee6daef6eb87f32c478e4da55b83e16a4850263d', 'b3fe9849d27c13e4bc1403d3e89dd476216746c2', '65ecd47cb1f5cbd298344fadfb28ce5928639398', 'df2e9b7f21a3f807aa578a0fa3f40b3db99b8d64', '15be47a07f9e405b5e574f48f8177a4216815e43', '19f5db7c447a0daec0adfe58ad71c8909555259f', '01c2f34a1ccdbd1e8c7a731f961ece39e25f4db3', '016f2a4ac75ff3cb6f21dc5636a13c6fe11a2e28', '575db902a12df8a2cc99cb6b6a4212cc58ee59df', '8816955147dfdfeb962ae9bc68cea590b5a64374', 'f6106a31d39ca7eb5118622903500a07eb2b2930']
# **** Saved backup of graph + queue at 454 papers.
# Processing paper e053f75f83e8ab22090b432387aa29eb2a7aff47 at depth 3
# ------- the num of references are:  21
# ------- the num of citations are:  1
# ------- the num of children are:  22
# ------- the rel references are:  ['8c74fa8a7636c82ab7c460aa25c7fb6b61eace9f', 'e664de730040907a410d694ab00a0f4acdf5c499', '8c545159efb4ab2b171e37418b6400c63ecd27ba']
# **** Saved backup of graph + queue at 455 papers.
# Processing paper 4b81e49f16f898005c37cba73ff6c5b706079caf at depth 3
# ------- the num of references are:  19
# ------- the num of citations are:  4
# ------- the num of children are:  23
# ------- the rel references are:  ['f8be8cc37a11aca32ba6e9f2fc32c7fc57e9fe35', 'c513e838af784c4d9ef460f9155b01431f352907', '663ddbec0b99670350fcfdb4b5a81537f2620536', '800368d107989fde4da18f254b660c4d384238d8', '9ca6bc590e0c1bfdd865462bfa114ac3a5470d4e']
# **** Saved backup of graph + queue at 456 papers.
# Processing paper 75bfc18859e4f5fa3c31d5c9b4129fc352a06373 at depth 3
# Seminal paper found: Trade does promote peace: New simultaneous estimates of the reciprocal effects of trade and conflict with 277 citations
# ------- the num of references are:  33
# ------- the num of citations are:  78
# ------- the num of children are:  111
# HTTP error occurred: 504 Server Error: Gateway Timeout for url: https://api.semanticscholar.org/graph/v1/paper/a4830ff258b5ce9df48190612828cd3216be155b?fields=title,abstract,url,year,authors,referenceCount,citationCount,citations,references - https://api.semanticscholar.org/graph/v1/paper/a4830ff258b5ce9df48190612828cd3216be155b?fields=title,abstract,url,year,authors,referenceCount,citationCount,citations,references
# ------- the rel references are:  ['86c1c52725a92f02a52bd9f7c6ad29abe69b4eb7', 'c513e838af784c4d9ef460f9155b01431f352907', 'f19a2dc676d0500835099a7b72b3bc5b26b20f5d', '9f91fa97f50bc6d6195b62bc39281fd7cda7a06e', '7355bd7a838d70e2e7ce859fa31a9f056d9051da', 'dd176a41ff3b0e0846f043f76be6448027b8ae02', '663ddbec0b99670350fcfdb4b5a81537f2620536', 'a1c80eb07dc307d2817e9b288fc9b8cabab87842', 'dc9b726d63f44bc0c2621a63007cf34c165ac65e', 'ab9828ff46c78e59814ec4d6224bd8412416f3fe', 'b0a55826b0318b1a0a2575b76f4fad5960cad3af', '5734cd54219a3480e8daca4664ea894d21d9fd68', '3a1f1ecba16183a318e99ebf72fe6fa40b42e330', '800368d107989fde4da18f254b660c4d384238d8', '4b4bfc2179e57f45bf9b8664a18cfcfad42ced05', 'fea3f03c8ac329ded873fd78434585d54907dc41', '7d30d423ca0c9cf7e6adf2c70de18b80d1413796', 'ee60ba5224e7233b20fab58b4b2419132fb2380f', 'b9538d77d70bd1d6f68980bb730eb314abc9b714', '5ccdb64c0d8415a00df99860d901b97373224931', 'b25e7941ae59b77572cbaffcc73a24fc00f6f735', 'd6cfb9b4d3e22e1b9c5a6d2ba01564ba15874574', '223ae4be0d3620d6c48f21f6abddb8b3e45600fa', '84bd934c819d01db86731884a2ceeb28998e53ff', '955df628e1e5d2a1f53cc056f267882a5359d08f', 'bad818033e07be79035d633cb3a29df421250686', 'c36f8fd6ad579756f4b368d21b1b1306b9df1927', '1b97e94d2cbe5de1ee975b5bed191e3cf74bc563', '8a3174c22cd37eaa851aeb7ae61409200c3b88cf', 'd5cfe45df320acf9d41f40c77df31d7006ddff72', '6443e76e632e4285f5b5f806592d603e8d06773d', '19618959d539093635a923950bc51ca20e187b1f', 'e499662782e9a1b484b1097f333ad40d977ea886', '134ceca1d4c5c4013586a400a414e836c4baca8d']
# **** Saved backup of graph + queue at 457 papers.
# Processing paper e5ab1cf0d783a238e630b0d58dc1771fd6b19395 at depth 3
# Seminal paper found: Public, Legislative, and Executive Constraints on the Democratic Initiation of Conflict with 165 citations
# ------- the num of references are:  6
# ------- the num of citations are:  38
# ------- the num of children are:  44
# ------- the rel references are:  ['fb11a2caa93f73035d504bc34b7329defff08c00', '800368d107989fde4da18f254b660c4d384238d8', 'f0c431642950ebac0da20750d8327be56e4db115', 'c3eec3e2cc7418962cbaf430e3e2fbea3c3559f9', '0aab4d4b8ed3fca293d05fcf9989050b94774978', 'ce7762c1fe329ff91e2afa5017188b09124c969c', 'ebe62538af18a56e3194c1b8718ef4c9579b7ffd', '275a5b80574e589e1640ea8cbdb7fc7a7871035b', 'fb11a2caa93f73035d504bc34b7329defff08c00', '3c9697f5d51a130bd4e5a6ede35532f1ce9cc99f', '134ceca1d4c5c4013586a400a414e836c4baca8d', '4c9ccc424001c4675cc0d6586f61b4d8e7782b75']
# **** Saved backup of graph + queue at 458 papers.
# Processing paper fc20c3aca1b4f5d57c0d4fd99314f33b2ea62bd1 at depth 3
# Seminal paper found: Civil Society and Social Capital Beyond Putnam with 375 citations
# ------- the num of references are:  4
# ------- the num of citations are:  66
# ------- the num of children are:  70
# ------- the rel references are:  ['624236a30770bc54db5ddee8689c9f21050018f2', '800368d107989fde4da18f254b660c4d384238d8', '4c5a59398838bd24bb96c9ea6435d6d1f89c7bf3', '476728935df124088bdf8158a8e65625f79e626e', '2a8a6566761b395747a26f4f609478bcfb6ffb3e']
# **** Saved backup of graph + queue at 459 papers.
# Processing paper 1fee1e6ae577ab013f7a6810d18cbbe883a96d30 at depth 3
# Seminal paper found: Bringing the State Back In: State Power and the Strength of Civil Society in the Southern Cone of Latin America with 138 citations
# ------- the num of references are:  0
# ------- the num of citations are:  26
# ------- the num of children are:  26
# ------- the rel references are:  ['800368d107989fde4da18f254b660c4d384238d8', '548e0b65f823d712e4ca41d1bbbb630d82df9ac7']
# **** Saved backup of graph + queue at 460 papers.
# Processing paper 1d3cac2d979379d4962a7a2ea5b2addb9961e275 at depth 3
# ------- the num of references are:  12
# ------- the num of citations are:  0
# ------- the num of children are:  12
# ------- the rel references are:  ['800368d107989fde4da18f254b660c4d384238d8', 'a242bc66d291bb19771f29c43760ea5c11d252c8']
# **** Saved backup of graph + queue at 461 papers.
# Processing paper 1edce12ceb52fddfaaa48314fe6c51ebf4658d1f at depth 3
# ------- the num of references are:  24
# ------- the num of citations are:  4
# ------- the num of children are:  28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 4
#       1 ## Actual generation
#       2 # time: 6 min 20s for 26 papers
# ----> 4 hist_network = generate_reference_network(hist_paper_id, max_depth=3, filter_func=filter_pred, res_name='hist_papers.json')
#
# Cell In[70], line 61, in generate_reference_network(start_paper_id, max_depth, filter_func, res_name)
#      59 if ref_id:
#      60     url = create_url(ref_id)
# ---> 61     res = try_api_call(url)
#      63     ## recompute
#      64     if not res:
#
# Cell In[29], line 19, in try_api_call(api_endpoint)
#      17 def try_api_call(api_endpoint):
#      18     try:
# ---> 19         response = requests.get(api_endpoint)
#      20         if response.status_code == 429:
#      21             print("Rate limit reached. Waiting before retrying...")
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/http/client.py:1411, in HTTPConnection.getresponse(self)
#    1409 try:
#    1410     try:
# -> 1411         response.begin()
#    1412     except ConnectionError:
#    1413         self.close()
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/http/client.py:324, in HTTPResponse.begin(self)
#     322 # read until we get a non-100 response
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#     326         break
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/http/client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#     287         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/ssl.py:1249, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1245     if flags != 0:
#    1246         raise ValueError(
#    1247           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1248           self.__class__)
# -> 1249     return self.read(nbytes, buffer)
#    1250 else:
#    1251     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/c-network/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
