# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %run cleaning_ucdp.ipynb
# %run cleaning_acled.ipynb

# %%
plot_ucdp(filename='somalia', region_name="Somalia")
# Out:
# dates range from 1989-01-01 to 2022-12-31

# %%
plot_acled(filename="Somalia 010197 030524", region_name='Somalia')
# Out:
# dates range from 1997-02-15 to 2024-03-01

# %%
plot_ucdp(filename='ethiopia', region_name="Ethiopia")
# Out:
# dates range from 1989-01-01 to 2022-12-28

# %%
plot_acled(filename="Ethiopia 010197 030524", region_name='Ethiopia')
# Out:
# dates range from 1997-01-15 to 2024-03-01

# %%
plot_ucdp(filename="south_sudan", region_name="South Sudan")
# Out:
# dates range from 2011-08-18 to 2022-12-24

# %%
plot_acled(filename="South Sudan 010197 030524", region_name='South Sudan')
# Out:
# dates range from 2011-05-19 to 2024-02-28
