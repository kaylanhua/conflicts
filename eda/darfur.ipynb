# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %run cleaning_ucdp.ipynb
# %run cleaning_acled.ipynb

# %%
plot_acled()
# Out:
# dates range from 1997-01-08 to 2023-09-29

# %%
plot_ucdp()

# date_range_ucdp = pd.date_range(start=min(dates_ucdp), end=max(dates_ucdp), periods=10)
# plt.xticks(ticks=date_range_ucdp, labels=[date.strftime('%Y-%m') for date in date_range_ucdp])

# plt.title('Fatalities Over Time (UCDP vs ACLED Darfur)')


# acled_sliced = acled_sorted[(acled_sorted["EVENT_DATE"] >= np.datetime64(min(dates_ucdp).date())) & 
#                             (acled_sorted["EVENT_DATE"] <= np.datetime64(max(dates_ucdp).date()))]
# dates_acled_sliced = acled_sliced["EVENT_DATE"]
# target_acled_sliced = acled_sliced["FATALITIES"]

# plt.plot(dates_acled_sliced, target_acled_sliced, label='ACLED Fatalities')  # Changed plot to scatterplot


# plt.legend()
# plt.show()
# Out:
# dates range from 1989-04-30 to 2022-12-23
